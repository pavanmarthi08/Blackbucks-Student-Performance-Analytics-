# %% [markdown]
# # Student Performance Analysis
#
# This notebook covers the Exploratory Data Analysis (EDA) and Machine Learning pipeline for the Student Analytics Dashboard.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sys
import os
sys.path.append(os.path.abspath('..'))
from src.data_processing import load_or_generate_data

# %%
# Load Data
df = load_or_generate_data('../data/student_performance.csv')
print(f"Dataset shape: {df.shape}")
df.head()

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# Missing Values
print(df.isnull().sum())

# %%
# Target Variable Distribution
plt.figure(figsize=(8, 5))
sns.histplot(df['Exam_Score'], bins=30, kde=True)
plt.title('Distribution of Final Exam Scores')
plt.show()

# %%
# Correlation Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes(include=[np.number]).corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# Machine Learning Pipeline Test
from src.model_training import train_and_evaluate

# This will evaluate Linear Regression, Random Forest, and Gradient Boosting
model, importance = train_and_evaluate('../data/student_performance.csv', '../models')

print("Done!")
